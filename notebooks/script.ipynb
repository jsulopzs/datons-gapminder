# %%
import pandas as pd

# %%
df = pd.read_csv('../data/gapminder.csv')

# %%
df['lifeExp'].hist()
# Out:
# <Axes: >

# %%
df['gdpPercap'].hist()
# Out:
# <Axes: >

# %%
df['gdpPercap'].hist()
# Out:
# <Axes: >
